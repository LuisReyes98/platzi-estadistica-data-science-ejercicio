# %% [markdown]
# # Exploración visual de los datos
#
# Ejemplos de dataviz
#
# https://datavizproject.com/
#
# ## Scatterplot
#
# Scatterplot o diagrama de dispersion, nos ayuda a entender como están relacionados dos variables con esto podemos identificar si existe alguna una correlación.

# %%
import pandas as pd 
import seaborn as sns

iris = sns.load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# scatterplot 
sns.scatterplot(
    data=iris,
    x='sepal_length',
    y='petal_length',
    hue='species'
)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(
    data=iris,
    x='sepal_length',
    y='petal_length',
    hue='species'
)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.jointplot(
    data=iris,
    x='sepal_length',
    y='petal_length'
)

# %% [markdown]
# http://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
# joint plot
sns.jointplot(
    data=iris,
    x='sepal_length',
    y='petal_length',
    hue='species'
)

# sns.jointplot(data=iris, x = 'sepal_length', y = 'petal_length', hue = 'species')

# %%
# joint plot
sns.jointplot(
    data=iris,
    x='sepal_length',
    y='petal_length',
    hue='species'
)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# joint plot
sns.jointplot(
    data=iris,
    x='petal_width',
    y='petal_length',
    hue='species'
)

# %%
sns.lmplot(
    data=iris,
    x='sepal_length',
    y='petal_length',
    hue='species'
)

# %%
# box plot 

sns.boxplot(
    data=iris,
    y='species',
    x='sepal_length'
)

# sns.boxplot(x = 'species', y = 'sepal_length', data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
#Barplot

g=sns.barplot(
    data=iris,
    x='species',
    y='sepal_length',
)
g.set_title("Longitud de sepalo ")

# sns.barplot(x = 'species', y = 'sepal_length', data = iris)
# Out:
# Text(0.5, 1.0, 'Longitud de sepalo ')

# %%
g=sns.barplot(
    data=iris,
    x='species',
    y='petal_length',
)
g.set_title("Longitud del petalo")
# Out:
# Text(0.5, 1.0, 'Longitud del petalo')

# %%
sns.barplot(
    data=iris,
    x='species',
    y='sepal_width'
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.pairplot(
    data=iris,
    hue='species',
    palette='inferno'
)

# %% [markdown]
# # Pipelines de procesamiento para variables numéricas
#
# ## Escalamiento lineal
#
# - Porque usarlos?
# Los Modelos de machine learning son optimos en que todos los atributos tienen las mismas dimensiones, suelen ser eficientes en el rango de [-1, 1]
#
# - Hay diferentes tipos de escalamiento?
# max-min, Clipping, Z-score, Winsorizing, etc..
#
# - Cuando usarlos?
# Data simetrica o uniformemente distribuida
#
#
# ### metodos
#
# #### Min max
#
# se tiene un valor X y se transforma a $X_s$ (X escalada linealmente)
# $$
# X_s = \frac{2x - \min - \max}{\max - \min}
# $$
#
# #### Clipping
# Es muy usado pero no es tan recomendado
#
# el valor transformado se obtiene definiendo un valor maximos y minimo de la distribucion y se fuerza a que todos los valores esten dentro de la distribucion
#
# el usar este metodo en machine learning no es recomendable ya que puedes acabar con datos que te serian utiles en tu analisis aunque sean outliers
#
# #### Z-score
#
# ${x_1, ... x_n } -> \mu,\sigma$
#
# $$
# X_s = \frac{x- \mu}{\sigma}
# $$
#
# esta transformacion hace que la mayoria de los valores esten dentro del rango de -1 y 1

# %% [markdown]
# ### Normalización
#
# La normalización es una técnica que a menudo se aplica como parte de la preparación de datos para el aprendizaje automático. El objetivo de la normalización es cambiar los valores de las columnas numéricas en el conjunto de datos para usar una escala común, sin distorsionar las diferencias en los rangos de valores ni perder información. La normalización también es necesaria para que algunos algoritmos modelen los datos correctamente.
# .
# Por ejemplo, suponga que su conjunto de datos de entrada contiene una columna con valores que van de 0 a 1 y otra columna con valores que van de 10,000 a 100,000. La gran diferencia en la escala de los números podría causar problemas al intentar combinar los valores como características durante el modelado.
# .
# La normalización evita estos problemas al crear nuevos valores que mantienen la distribución general y las proporciones en los datos de origen, mientras mantienen los valores dentro de una escala aplicada en todas las columnas numéricas utilizadas en el modelo.
# .
#
# **Tenemos varias opciones para transformar datos numéricos:**
#
# - Cambiar todos los valores a una escala de 0 a 1 o transformar los valores representándolos como rangos de percentiles en lugar de valores absolutos.
# - Aplicar la normalización a una sola columna o a varias columnas en el mismo conjunto de datos.
# - Si necesita repetir el experimento o aplicar los mismos pasos de normalización a otros datos, puede guardar los pasos como una transformación de normalización y aplicarlos a otros conjuntos de datos que tengan el mismo esquema.
#
# >Nota importante: Algunos algoritmos requieren que los datos se normalicen antes de entrenar un modelo. Otros algoritmos realizan su propia normalización o escalado de datos.
#
# #### Normalización lineal
# **Algunos de los tipos:**
#
# - **Zscore:** convierte todos los valores en una puntuación z. Los valores de la columna se transforman mediante la siguiente fórmula:
# z score
#
# $$
# z= \frac{x - \mu(x)}{\sigma(x)}
# $$
#
# La media y la desviación estándar se calculan para cada columna por separado. Se utiliza la desviación estándar de la población.
#
#
#
# - **MinMax:** el normalizador min-max cambia la escala linealmente cada característica al intervalo [0,1]. El cambio de escala al intervalo [0,1] se realiza cambiando los valores de cada característica para que el valor mínimo sea 0, y luego dividiendo por el nuevo valor máximo (que es la diferencia entre los valores máximo y mínimo originales). Los valores de la columna se transforman mediante la siguiente fórmula:
# min max
#
# $$
# z= \frac{x - \min(x)}{[\max(x) - \min(x)]}
# $$
#
# ¿Cuándo usar la normalización lineal?
#
# - En datos simétricos o en datos uniformemente distribuidos.

# %% [markdown]
# # Transformación no lineal
#
# consiste en tomar los datos de una distribucion No simetrica y transformarlos para trabajarlos como si fueran una distribucion simetrica
#
# - **Porque Usarlos?**
# Datos fuertemente sesgados, no simetricos
#
# - **Hay diferentes tipos?**
# Logaritmos, sigmoides, polinomiales, etc...
#
# - **Cuando Usarlos ?**
# Antes de escalamientos lineales!!
#
#
#
# ## Ejemplo
#
# aplicar la $\tanh(x)$  ya que todos los valores resultantes se encuentran en un rango entre -1 y 1
#
# siendo Xs
#
# $$
# X_s = \tanh(x)
# $$
#
# que tanto se acerca la distribucion transformada a una distribucion Normal depende de la funcion aplicada
#
# otra posible es aplicar la sigmoide
#
# $$S(x)= \frac {1}{1+e^{-x}}$$
#
# otro posible es aplicar la raiz cuadrada de x : $$\sqrt{x}$$

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bc504059-8ad6-4235-92fa-88fa0fec1687' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
